# %% [markdown]
# # Домашнє завдання Тема 2

# %% [markdown]
# ## 1. Підготовка зображень

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import requests
from io import BytesIO
import numpy as np
from PIL import Image
from sklearn.decomposition import TruncatedSVD

# Вставте URL-адреси зображень
image_urls = [
    "https://www.tailorbrands.com/wp-content/uploads/2020/07/apple-logo.jpg",
    "https://www.tailorbrands.com/wp-content/uploads/2020/07/mcdonalds-logo.jpg",
    "https://www.tailorbrands.com/wp-content/uploads/2020/07/twitter-logo.jpg",
    # додайте більше URL-адрес за потреби
]

# %%
# Виведення та обробка зображень
for url in image_urls:
    response = requests.get(url)
    img = Image.open(BytesIO(response.content)).convert("RGB")
    img = np.array(img)

    # Відображення зображення
    plt.imshow(img)
    plt.axis('off')  # Приховати осі
    plt.title(f'Зображення з URL: {url}')
    plt.show()

    # Визначення розміру зображення
    print(f'Розмір зображення з URL {url}: {img.shape}')

    # змінити форму зображення з 3D-матриці на 2D-матрицю шляхом укладання кольорових каналів горизонтально
    height, width, channels = img.shape
    flat_image = img.reshape(-1, width * channels)

    plt.imshow(flat_image)
    plt.axis('off')  # Приховати осі
    plt.title(f'Зображення в 2D (плоске)')
    plt.show()
    print(f'Розмір зображення в 2D: {flat_image.shape}')


    # Обчислення SVD розкладу
    U, S, Vt = np.linalg.svd(flat_image, full_matrices=False)
    print(f"Shape of U={U.shape}")
    print(f"Shape of S={S.shape}")
    print(f"Shape of Vt={Vt.shape}")

    # Візуалізація сингулярних значень
    k = 10  # можна змінити це значення на будь-яке інше для візуалізації
    plt.plot(np.arange(k), S[:k])
    plt.xlabel('Ранг сингулярного значення')
    plt.ylabel('Величина сингулярного значення')
    plt.title('Сингулярні значення')
    plt.show()

    # Обрізати зображення за допомогою SVD
    nums = [5, 15, 30, 50, 75, 100]
    for num in nums:
        svd = TruncatedSVD(n_components=num)
        truncated_image = svd.fit_transform(flat_image)
        print()
        print('Розмір стиснутого зображення з n-компонентом', num, ': ', truncated_image.shape)

        print('Відновлення . . . .')
        # Відновити зображення зі зменшеного представлення
        reconstructed_image = svd.inverse_transform(truncated_image)

        # розрахунок помилки реконструкції:
        reconstruction_error = np.mean(np.square(reconstructed_image - flat_image))
        print("    Помилка реконструкції", reconstruction_error)

        # Змінити форму зображення до оригінальної 3D форми
        reconstructed_image = reconstructed_image.reshape(height, width, channels)

        # Обрізати вихідні дані до цілих чисел у діапазоні [0, 255]
        reconstructed_image = np.clip(reconstructed_image, 0 , 255 ).astype( 'uint8' )
        print('    Розмір відновленого зображення', reconstructed_image.shape)

        # Відображення оригінального та відновленого зображень
        fig, axes = plt.subplots(1, 2, figsize=(12, 6))
        axes[0].imshow(img)
        axes[0].set_title('Оригінальне зображення')
        axes[0].axis('off')

        axes[1].imshow(reconstructed_image)
        axes[1].set_title(f'Якість відновлення: {num} компонентів')
        axes[1].axis('off')

        plt.show()

# Збереження зображення на жорсткий диск (якщо потрібно)
# plt.savefig('reconstructed_image.jpg')
# Out:
# Розмір зображення з URL https://www.tailorbrands.com/wp-content/uploads/2020/07/apple-logo.jpg: (468, 466, 3)
# Розмір зображення в 2D: (468, 1398)
# Shape of U=(468, 468)
# Shape of S=(468,)
# Shape of Vt=(468, 1398)
# Розмір стиснутого зображення з n-компонентом 5 :  (468, 5)
# Відновлення . . . .
#     Помилка реконструкції 63.21984766586966
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 15 :  (468, 15)
# Відновлення . . . .
#     Помилка реконструкції 17.429895229954425
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 30 :  (468, 30)
# Відновлення . . . .
#     Помилка реконструкції 6.515270268279317
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 50 :  (468, 50)
# Відновлення . . . .
#     Помилка реконструкції 2.28141897687149
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 75 :  (468, 75)
# Відновлення . . . .
#     Помилка реконструкції 0.7094051684226411
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 100 :  (468, 100)
# Відновлення . . . .
#     Помилка реконструкції 0.22324847669053657
#     Розмір відновленого зображення (468, 466, 3)
# Розмір зображення з URL https://www.tailorbrands.com/wp-content/uploads/2020/07/mcdonalds-logo.jpg: (468, 466, 3)
# Розмір зображення в 2D: (468, 1398)
# Shape of U=(468, 468)
# Shape of S=(468,)
# Shape of Vt=(468, 1398)
# Розмір стиснутого зображення з n-компонентом 5 :  (468, 5)
# Відновлення . . . .
#     Помилка реконструкції 152.64201870346386
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 15 :  (468, 15)
# Відновлення . . . .
#     Помилка реконструкції 14.597296449499055
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 30 :  (468, 30)
# Відновлення . . . .
#     Помилка реконструкції 2.9656021170325166
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 50 :  (468, 50)
# Відновлення . . . .
#     Помилка реконструкції 0.7498435982050011
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 75 :  (468, 75)
# Відновлення . . . .
#     Помилка реконструкції 0.2792907481155385
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 100 :  (468, 100)
# Відновлення . . . .
#     Помилка реконструкції 0.14259693654115882
#     Розмір відновленого зображення (468, 466, 3)
# Розмір зображення з URL https://www.tailorbrands.com/wp-content/uploads/2020/07/twitter-logo.jpg: (468, 466, 3)
# Розмір зображення в 2D: (468, 1398)
# Shape of U=(468, 468)
# Shape of S=(468,)
# Shape of Vt=(468, 1398)
# Розмір стиснутого зображення з n-компонентом 5 :  (468, 5)
# Відновлення . . . .
#     Помилка реконструкції 270.4362180428948
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 15 :  (468, 15)
# Відновлення . . . .
#     Помилка реконструкції 71.10858580412464
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 30 :  (468, 30)
# Відновлення . . . .
#     Помилка реконструкції 23.980071832124413
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 50 :  (468, 50)
# Відновлення . . . .
#     Помилка реконструкції 8.987072400183129
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 75 :  (468, 75)
# Відновлення . . . .
#     Помилка реконструкції 3.56660739799979
#     Розмір відновленого зображення (468, 466, 3)
# Розмір стиснутого зображення з n-компонентом 100 :  (468, 100)
# Відновлення . . . .
#     Помилка реконструкції 1.5874694507992928
#     Розмір відновленого зображення (468, 466, 3)

# %% [markdown]
# # Висновок
#
# У цьому експерименті ми використовували сингулярний розклад (SVD) для аналізу та відновлення зображень, що дозволяє зменшити їх розмір за рахунок збереження лише найбільш значущих компонентів.
#
# Графік сингулярних значень: На графіку сингулярних значень можна спостерігати, що величини сингулярних значень швидко зменшуються, особливо до 2-го рангу. Це свідчить про те, що більшість інформації зображення зосереджена в перших кількох компонентах.
#
# Якість відновленого зображення:
# - Незважаючи на те, що сингулярні значення швидко зменшуються, якість відновленого зображення покращується зі збільшенням кількості компонентів (n_components). Це означає, що для досягнення високої якості зображення потрібно використовувати більше компонентів.
# - Забраження набуває впізнаваємості (хоча розмита) починаючи з 15 компонентів коли помилка реконструкції знижується до 20.
# - Для зображення з невеликими відхиленнями якість відновлення досягає стабільного рівня приблизно при n_components = 50, де помилка реконструкції становить близько 2.0.
# - Ідеальна якість зображення досягається при n_components = 100, де помилка реконструкції зменшується до 0.2.
# - Для різних зображень показники різняться різняться як в суб'єктивному сприйнятті якості відновлення, так і в числах помилки реконструкції
#
#
# Ці результати показують, що хоча більшість важливої інформації міститься в перших кількох сингулярних значеннях, для досягнення високої якості зображення може знадобитися збереження більшої кількості компонентів. Використання менше компонентів може призвести до значних відхилень у якості зображення, тому вибір оптимальної кількості компонентів є критично важливим для досягнення бажаного балансу між стисненням і якістю відновлення.
